# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
items = {'Congruent' : pd.Series(data = [12.079,16.791,9.564,8.63,14.669,12.238,14.692,8.987,9.401,14.48,22.328,15.298,15.073,16.929,18.2,12.13,18.495,10.639,11.344,12.369,12.944,14.233,19.71,16.004]), 'Incongruent' : pd.Series(data = [19.278,18.741,21.214,15.687,22.803,20.878,24.572,17.394,20.762,26.282,24.524,18.644,17.51,20.33,35.255,22.158,25.139,20.429,17.425,34.288,23.894,17.96,22.058,21.157])}
df = pd.DataFrame(items)
print(df['Congruent'].describe())
print(df['Incongruent'].describe())
# Out:
# count    24.000000
# mean     14.051125
# std       3.559358
# min       8.630000
# 25%      11.895250
# 50%      14.356500
# 75%      16.200750
# max      22.328000
# Name: Congruent, dtype: float64
# count    24.000000
# mean     22.015917
# std       4.797057
# min      15.687000
# 25%      18.716750
# 50%      21.017500
# 75%      24.051500
# max      35.255000
# Name: Incongruent, dtype: float64

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot( df["Congruent"] , color="skyblue",  kde_kws={"color": "skyblue", "lw": 3, "label": "Congruent"})
ax = sns.distplot( df["Incongruent"] , color="red", kde_kws={"color": "red", "lw": 3, "label": "Incongruent"})
ax.set(xlabel='Response Time', ylabel='Relative Frequency')
# Out:
# /Volumes/Drive2/App/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Volumes/Drive2/App/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0,0.5,'Relative Frequency'), Text(0.5,0,'Response Time')]
